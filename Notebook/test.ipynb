# %%
import importlib

import tifffile
import skimage as ski
import napari
import dask
import dask.array as da
import zarr

import cropper._widget
from cropper._widget import crop_widget

# %%
viewer = napari.Viewer()
# Out:
# napari.manifest -> 'napari-cropper' could not be imported: The name field in the manifest ('cropper') must match the package name ('napari-cropper')

# %%
xfile = "/n/core/micro/lil/yp3002/2026/June-July/20260707_AT2_IMARE-147953/stitched/R26rc_Lgr5+c_Msi+d_2mo_4mg_TMX_001_MAX.ome.tif"
tx = tifffile.TiffFile(xfile)

# %%
rgbfile = "20150627_093138_Pano.jpg"
x = ski.io.imread(rgbfile)

# %%
viewer.add_image(x)
# Out:
# <Image layer 'x' at 0x7f48c2325160>

# %%
viewer.layers[0].data.shape
# Out:
# (2067, 7738, 3)

# %%
store = tifffile.imread(xfile, aszarr=True)
z = zarr.open(store, mode="r")

metadata = z.metadata

levels = [z[k] for k in sorted(z.keys())]
levels

# %%
viewer.add_image(levels, channel_axis=0, multiscale=True)

# %%
old_widg = crop_widget
importlib.reload(cropper._widget)
from cropper._widget import crop_widget 

viewer.window.remove_dock_widget('all')  # old instance, before reassigning
viewer.window.add_dock_widget(crop_widget())  # new instance
# Out:
# [[ 142.95471 3187.4805 ]
#  [ 142.95471 3668.4639 ]
#  [ 430.64612 3668.4639 ]
#  [ 430.64612 3187.4805 ]]
# 142 430 3187 3668
# (288, 481, 3)
# 1
# (288, 481, 3) (288, 481, 3) YXC
# Traceback (most recent call last):
#   File "/n/projects/cjw/PythonCode/NapariCropper/.venv/lib/python3.12/site-packages/napari/_qt/qt_viewer.py", line 1271, in dropEvent
#     self._open_from_list_of_urls_data(
#   File "/n/projects/cjw/PythonCode/NapariCropper/.venv/lib/python3.12/site-packages/napari/_qt/qt_viewer.py", line 1288, in _open_from_list_of_urls_data
#     self._qt_open(
#   File "/n/projects/cjw/PythonCode/NapariCropper/.venv/lib/python3.12/site-packages/napari/_qt/qt_viewer.py", line 1098, in _qt_open
#     self.viewer.open(
#   File "/n/projects/cjw/PythonCode/NapariCropper/.venv/lib/python3.12/site-packages/napari/components/viewer_model.py", line 1547, in open
#     layers = self._open_or_raise_error(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/n/projects/cjw/PythonCode/NapariCropper/.venv/lib/python3.12/site-packages/napari/components/viewer_model.py", line 1615, in _open_or_raise_error
#     raise NoAvailableReaderError(
# napari.errors.reader_errors.NoAvailableReaderError: No plugin found capable of reading /n/core/micro/lil/zy2611/lem/20260429_OSS_IMARE-145638/Image_09 - 40x_05.vsi.

# %%
md = viewer.layers[0].data

# %%
metadata: zarr.core.group.GroupMetadata = z.metadata
